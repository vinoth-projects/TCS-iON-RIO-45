# %%
import pandas as pd
import re
import string

# Function to clean text
def clean_text(text):
    # Remove emojis
    text = re.sub(r'[^\x00-\x7F]+', '', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Lowercase
    text = text.lower()
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Step 1: Manually load and clean CSV file
cleaned_data = []
with open(r"C:\Users\ASUS\Downloads\CSV_file.csv", "r", encoding="utf-8") as file:
    for line in file:
        line = line.strip().strip('"')
        parts = line.split(",", 3)
        if len(parts) == 4:
            cleaned_data.append(parts)

# Step 2: Create DataFrame
df = pd.DataFrame(cleaned_data[1:], columns=["Index", "Emotion", "Text", "Clean_Text"])

# Step 3: Preprocess Text
df["Processed_Text"] = df["Text"].apply(clean_text)

# Optional: Map detailed emotions to Sentiment categories
emotion_to_sentiment = {
    "joy": "Positive",
    "love": "Positive",
    "happy": "Positive",
    "neutral": "Neutral",
    "surprise": "Neutral",
    "sadness": "Negative",
    "anger": "Negative",
    "fear": "Negative"
}
df["Sentiment"] = df["Emotion"].map(emotion_to_sentiment).fillna("Neutral")

# Step 4: Show 50 random samples with sentiment
sample_reviews = df[["Processed_Text", "Sentiment"]].sample(n=50, random_state=42)

# Step 5: Print results
for i, row in enumerate(sample_reviews.itertuples(), 1):
    print(f"{i}. [{row.Sentiment}] {row.Processed_Text}")
# Out:
# 1. [Negative] cody wont be coming anywhere near where i live at all
# 2. [Negative] woah
# 3. [Negative] forgive me
# 4. [Positive] great
# 5. [Negative] people dont even know how blessed u can be when youra a medical student nothing ever goes smoothly
# 6. [Positive] two classes orchestra amp a meeting for work
# 7. [Negative] revrunwisdom not afraid of tomorrow
# 8. [Neutral] twenty
# 9. [Neutral] terrible
# 10. [Positive] so my precal final is at 7 amguess i am going to be pulling an allnighter oo
# 11. [Negative] comme au match aller
# 12. [Negative] despite the sadness of the occasion
# 13. [Negative] my mother died of cancer after a 4 year illness i think the most pregnant moment of sadness was the next morning
# 14. [Neutral] not bad
# 15. [Negative] an unjust calumny concerning me
# 16. [Neutral] andiecrispy amp luzou si je vous fais un sneak peak de mon chapeau
# 17. [Positive] last day commuting aka last day taking the horrendous academybus line bestdayofmylife
# ...
